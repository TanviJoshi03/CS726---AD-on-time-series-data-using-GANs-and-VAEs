# %% [markdown]
# ## LSTM-VAE-GAN

# %%
import os
import random
import torch
import torch.nn as nn
import torch.backends.cudnn as cudnn
import torch.optim as optim
import torch.utils.data
import torchvision
import torch.nn.init as init
from torch.autograd import Variable
import datetime
from nab_dataset import NabDataset
from models.LVG import LSTMVAEGenerator, LSTMVAEDiscriminator

import matplotlib.pyplot as plt

# %%
class ArgsTrn:
    workers=4
    batch_size= 128 #original wa 32
    epochs=50 #original was 100
    lr=0.002 #original was 0.0002
    cuda = True
    manualSeed=88

opt_trn=ArgsTrn()
torch.manual_seed(opt_trn.manualSeed)
cudnn.benchmark = True

# %%
window_length = 60
hidden_dim = 64
latent_dim = 32

# %%
end_name = 'machine_temperature_system_failure.csv' # dataset name
data_file = 'data/realKnownCause/'+end_name # dataset category and dataset name
key = 'realKnownCause/'+end_name # This key is used for reading anomaly labels

# %%
# settings for data loader
class DataSettings:
    
    def __init__(self):
        self.BASE = '/users/extusr/kaustavprasad/Datasets/NAB/'
        self.label_file = 'labels/combined_windows.json'
        self.data_file = data_file
        self.key = key
        self.train = True
        self.window_length = window_length
    
    
data_settings = DataSettings()

# %%
# define dataset object and data loader object for NAB dataset
dataset = NabDataset(data_settings=data_settings)
dataloader = torch.utils.data.DataLoader(dataset, batch_size=opt_trn.batch_size,
                                         shuffle=True, num_workers=int(opt_trn.workers))

dataset.x.shape, dataset.y.shape # check the dataset shape
# Out:
# (torch.Size([22635, 60, 1]), torch.Size([22635]))

# %%
max_index = 3
for i, (x, y) in enumerate(dataloader):
    if i >= max_index: break
    print(x.shape, y.shape)
    plt.plot(x[0, :, 0])
# Out:
# torch.Size([128, 60, 1]) torch.Size([128])
# torch.Size([128, 60, 1]) torch.Size([128])
# torch.Size([128, 60, 1]) torch.Size([128])

# %%
device = torch.device("cuda:0" if opt_trn.cuda else "cpu") # select the device
seq_len = dataset.window_length # sequence length is equal to the window length
in_dim = dataset.n_feature # input dimension is same as number of feature

# %%
netG = LSTMVAEGenerator(
    in_dim=in_dim,
    out_dim=in_dim,
    latent_dim=latent_dim,
    hidden_dim=hidden_dim,
    n_layers=1,
    device=device).to(device)

netD = LSTMVAEDiscriminator(
    in_dim=in_dim,
    latent_dim=latent_dim,
    hidden_dim=hidden_dim,
    n_layers=1,
    device=device).to(device)
# Out:
# /users/extusr/kaustavprasad/miniconda3/envs/mlpy/lib/python3.11/site-packages/torch/nn/modules/rnn.py:71: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "

# %%
print("|Generator Architecture|\n", netG)
print("|Discriminator Architecture|\n", netD)
# Out:
# |Generator Architecture|
#  LSTMVAEGenerator(
#   (encoder): Sequential(
#     (0): Linear(in_features=1, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=32, bias=True)
#     (3): ReLU()
#   )
#   (lstm): LSTM(32, 64, batch_first=True, dropout=0.5)
#   (decoder): Sequential(
#     (0): Linear(in_features=64, out_features=2, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=2, out_features=1, bias=True)
#     (3): Sigmoid()
#   )
# )
# |Discriminator Architecture|
#  LSTMVAEDiscriminator(
#   (encoder): Sequential(
#     (0): Linear(in_features=1, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=32, bias=True)
#     (3): ReLU()
#   )
#   (lstm): LSTM(32, 64, batch_first=True, dropout=0.5)
#   (decoder): Sequential(
#     (0): Linear(in_features=64, out_features=2, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=2, out_features=1, bias=True)
#     (3): Sigmoid()
#   )
# )

# %%
criterion = nn.BCELoss().to(device)

# %%
optimizerD = optim.Adam(netD.parameters(), lr=opt_trn.lr)
optimizerG = optim.Adam(netG.parameters(), lr=opt_trn.lr)

# %%
losses_G, losses_D = [], []

# %%
verbose = False

real_label = 1
fake_label = 0

for epoch in range(opt_trn.epochs):
    for i, (x,y) in enumerate(dataloader, 0):
        
        ############################
        # (1) Update D network: maximize log(D(x)) + log(1 - D(G(z)))
        ###########################

        #Train with real data
        netD.zero_grad()
        real = x.to(device)
        batch_size, seq_len = real.size(0), real.size(1)
        label = torch.full((batch_size, seq_len, 1), real_label, device=device)

        if verbose==True: print("Discriminator input shape:", real.shape)

        output = netD.forward(real)

        if verbose==True: print("Discriminator output shape:", output.shape)


        errD_real = criterion(output, label.float())
        errD_real.backward()
        optimizerD.step()
        D_x = output.mean().item()
        
        #Train with fake data
        noise = Variable(init.normal(torch.Tensor(batch_size,seq_len,in_dim),mean=0,std=0.1)).cuda()
        
        if verbose==True: print("Noise shape:", noise.shape)
        
        fake = netG.forward(noise)
        
        if verbose==True: print("Generator Output shape:", fake.shape)

        output = netD.forward(fake.detach()) # detach causes gradient is no longer being computed or stored to save memeory
        label.fill_(fake_label)
        errD_fake = criterion(output, label.float())
        errD_fake.backward()
        D_G_z1 = output.mean().item()
        errD = errD_real + errD_fake
        optimizerD.step()
        
        ############################
        # (2) Update G network: maximize log(D(G(z)))
        ###########################
        netG.zero_grad()
        noise = Variable(init.normal(torch.Tensor(batch_size,seq_len,in_dim),mean=0,std=0.1)).cuda()
        fake = netG.forward(noise)
        label.fill_(real_label) 
        output = netD.forward(fake)
        errG = criterion(output, label.float())
        errG.backward()
        optimizerG.step()
        D_G_z2 = output.mean().item()  

    print('[%d/%d][%d/%d] Loss_D: %.4f Loss_G: %.4f D(x): %.4f D(G(z)): %.4f / %.4f' 
          % (epoch, opt_trn.epochs, i, len(dataloader),
             errD.item(), errG.item(), D_x, D_G_z1, D_G_z2), end='')
    
    losses_G.append(errG.item())
    losses_D.append(errD.item())
    print()
# Out:
# /tmp/ipykernel_2808648/2106613691.py:32: UserWarning: nn.init.normal is now deprecated in favor of nn.init.normal_.
#   noise = Variable(init.normal(torch.Tensor(batch_size,seq_len,in_dim),mean=0,std=0.1)).cuda()
# /tmp/ipykernel_2808648/2106613691.py:52: UserWarning: nn.init.normal is now deprecated in favor of nn.init.normal_.
#   noise = Variable(init.normal(torch.Tensor(batch_size,seq_len,in_dim),mean=0,std=0.1)).cuda()
# [0/50][176/177] Loss_D: 1.4295 Loss_G: 0.5065 D(x): 0.6023 D(G(z)): 0.6025 / 0.6026
# [1/50][176/177] Loss_D: 1.4653 Loss_G: 0.4498 D(x): 0.6376 D(G(z)): 0.6377 / 0.6378
# [2/50][176/177] Loss_D: 1.4851 Loss_G: 0.4257 D(x): 0.6533 D(G(z)): 0.6533 / 0.6533
# [3/50][176/177] Loss_D: 1.4949 Loss_G: 0.4149 D(x): 0.6604 D(G(z)): 0.6604 / 0.6604
# [4/50][176/177] Loss_D: 1.4997 Loss_G: 0.4100 D(x): 0.6637 D(G(z)): 0.6637 / 0.6637
# [5/50][176/177] Loss_D: 1.5020 Loss_G: 0.4076 D(x): 0.6652 D(G(z)): 0.6653 / 0.6652
# [6/50][176/177] Loss_D: 1.5031 Loss_G: 0.4065 D(x): 0.6660 D(G(z)): 0.6660 / 0.6660
# [7/50][176/177] Loss_D: 1.5036 Loss_G: 0.4060 D(x): 0.6663 D(G(z)): 0.6664 / 0.6663
# [8/50][176/177] Loss_D: 1.5039 Loss_G: 0.4057 D(x): 0.6665 D(G(z)): 0.6665 / 0.6665
# [9/50][176/177] Loss_D: 1.5040 Loss_G: 0.4056 D(x): 0.6666 D(G(z)): 0.6666 / 0.6666
# [10/50][176/177] Loss_D: 1.5041 Loss_G: 0.4055 D(x): 0.6666 D(G(z)): 0.6666 / 0.6666
# [11/50][176/177] Loss_D: 1.5041 Loss_G: 0.4055 D(x): 0.6666 D(G(z)): 0.6667 / 0.6666
# [12/50][176/177] Loss_D: 1.5041 Loss_G: 0.4055 D(x): 0.6666 D(G(z)): 0.6667 / 0.6666
# [13/50][176/177] Loss_D: 1.5041 Loss_G: 0.4055 D(x): 0.6667 D(G(z)): 0.6667 / 0.6667
# [14/50][176/177] Loss_D: 1.5041 Loss_G: 0.4055 D(x): 0.6667 D(G(z)): 0.6667 / 0.6667
# [15/50][176/177] Loss_D: 1.5041 Loss_G: 0.4055 D(x): 0.6667 D(G(z)): 0.6667 / 0.6667
# [16/50][176/177] Loss_D: 1.5041 Loss_G: 0.4055 D(x): 0.6667 D(G(z)): 0.6667 / 0.6667
# [17/50][176/177] Loss_D: 1.5041 Loss_G: 0.4055 D(x): 0.6667 D(G(z)): 0.6667 / 0.6667
# [18/50][176/177] Loss_D: 1.5041 Loss_G: 0.4055 D(x): 0.6667 D(G(z)): 0.6667 / 0.6667
# [19/50][176/177] Loss_D: 1.5041 Loss_G: 0.4055 D(x): 0.6667 D(G(z)): 0.6667 / 0.6667
# [20/50][176/177] Loss_D: 1.5041 Loss_G: 0.4055 D(x): 0.6667 D(G(z)): 0.6667 / 0.6667
# [21/50][176/177] Loss_D: 1.5041 Loss_G: 0.4055 D(x): 0.6667 D(G(z)): 0.6667 / 0.6667
# [22/50][176/177] Loss_D: 1.5041 Loss_G: 0.4055 D(x): 0.6667 D(G(z)): 0.6667 / 0.6667
# [23/50][176/177] Loss_D: 1.5041 Loss_G: 0.4055 D(x): 0.6667 D(G(z)): 0.6667 / 0.6667
# [24/50][176/177] Loss_D: 1.5041 Loss_G: 0.4055 D(x): 0.6667 D(G(z)): 0.6667 / 0.6667
# [25/50][176/177] Loss_D: 1.5041 Loss_G: 0.4055 D(x): 0.6667 D(G(z)): 0.6667 / 0.6667
# [26/50][176/177] Loss_D: 1.5041 Loss_G: 0.4055 D(x): 0.6667 D(G(z)): 0.6667 / 0.6667
# [27/50][176/177] Loss_D: 1.5041 Loss_G: 0.4055 D(x): 0.6667 D(G(z)): 0.6667 / 0.6667
# [28/50][176/177] Loss_D: 1.5041 Loss_G: 0.4055 D(x): 0.6667 D(G(z)): 0.6667 / 0.6667
# [29/50][176/177] Loss_D: 1.5041 Loss_G: 0.4055 D(x): 0.6667 D(G(z)): 0.6667 / 0.6667
# [30/50][176/177] Loss_D: 1.5041 Loss_G: 0.4055 D(x): 0.6667 D(G(z)): 0.6667 / 0.6667
# [31/50][176/177] Loss_D: 1.5041 Loss_G: 0.4055 D(x): 0.6667 D(G(z)): 0.6667 / 0.6667
# [32/50][176/177] Loss_D: 1.5041 Loss_G: 0.4055 D(x): 0.6667 D(G(z)): 0.6667 / 0.6667
# [33/50][176/177] Loss_D: 1.5041 Loss_G: 0.4055 D(x): 0.6667 D(G(z)): 0.6667 / 0.6667
# [34/50][176/177] Loss_D: 1.5041 Loss_G: 0.4055 D(x): 0.6667 D(G(z)): 0.6667 / 0.6667
# [35/50][176/177] Loss_D: 1.5041 Loss_G: 0.4055 D(x): 0.6667 D(G(z)): 0.6667 / 0.6667
# [36/50][176/177] Loss_D: 1.5041 Loss_G: 0.4055 D(x): 0.6667 D(G(z)): 0.6667 / 0.6667
# [37/50][176/177] Loss_D: 1.5041 Loss_G: 0.4055 D(x): 0.6667 D(G(z)): 0.6667 / 0.6667
# [38/50][176/177] Loss_D: 1.5041 Loss_G: 0.4055 D(x): 0.6667 D(G(z)): 0.6667 / 0.6667
# [39/50][176/177] Loss_D: 1.5041 Loss_G: 0.4055 D(x): 0.6667 D(G(z)): 0.6667 / 0.6667
# [40/50][176/177] Loss_D: 1.5041 Loss_G: 0.4055 D(x): 0.6667 D(G(z)): 0.6667 / 0.6667
# [41/50][176/177] Loss_D: 1.5041 Loss_G: 0.4055 D(x): 0.6667 D(G(z)): 0.6667 / 0.6667
# [42/50][176/177] Loss_D: 1.5041 Loss_G: 0.4055 D(x): 0.6667 D(G(z)): 0.6667 / 0.6667
# [43/50][176/177] Loss_D: 1.5041 Loss_G: 0.4055 D(x): 0.6667 D(G(z)): 0.6667 / 0.6667
# [44/50][176/177] Loss_D: 1.5041 Loss_G: 0.4055 D(x): 0.6667 D(G(z)): 0.6667 / 0.6667
# [45/50][176/177] Loss_D: 1.5041 Loss_G: 0.4055 D(x): 0.6667 D(G(z)): 0.6667 / 0.6667
# [46/50][176/177] Loss_D: 1.5041 Loss_G: 0.4055 D(x): 0.6667 D(G(z)): 0.6667 / 0.6667
# [47/50][176/177] Loss_D: 1.5041 Loss_G: 0.4055 D(x): 0.6667 D(G(z)): 0.6667 / 0.6667
# [48/50][176/177] Loss_D: 1.5041 Loss_G: 0.4055 D(x): 0.6667 D(G(z)): 0.6667 / 0.6667
# [49/50][176/177] Loss_D: 1.5041 Loss_G: 0.4055 D(x): 0.6667 D(G(z)): 0.6667 / 0.6667

# %%
plt.plot(losses_D, label='Discriminator Loss')
plt.plot(losses_G, label='Generator Loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %% [markdown]
# ## Anomaly Score

# %%
class ArgsTest:
    workers = 1
    batch_size = 1
    z_learning_rate = 0.02
    grad_descent_iterations = 50
    
opt_test=ArgsTest()

# %%
generator = netG 
discriminator = netD

# %%
class TestDataSettings:
    
    def __init__(self):
        self.BASE = '/users/extusr/kaustavprasad/Datasets/NAB/'
        self.label_file = 'labels/combined_windows.json'
        self.data_file = data_file
        self.key = key
        self.train = False

        
test_data_settings = TestDataSettings()

# %%
test_dataset = NabDataset(test_data_settings)
test_dataloader = torch.utils.data.DataLoader(test_dataset, batch_size=opt_test.batch_size, 
                                         shuffle=False, num_workers=int(opt_test.workers))

test_dataset.x.shape, test_dataset.y.shape, test_dataset.data_len # check the dataset shape
# Out:
# (torch.Size([378, 60, 1]), torch.Size([378]), 378)

# %%
# Lambda = 0.1 according to paper
# x is new data, G_z is closely regenerated data

def Anomaly_score(x, G_z, Lambda=0.1):
    residual_loss = torch.sum(torch.abs(x-G_z)) # Residual Loss
    
    # x_feature is a rich intermediate feature representation for real data x
    x_feature = discriminator(x.to(device)) 
    # G_z_feature is a rich intermediate feature representation for fake data G(z)
    G_z_feature = discriminator(G_z.to(device)) 
    
    discrimination_loss = torch.sum(torch.abs(x_feature-G_z_feature)) # Discrimination loss
    
    total_loss = (1-Lambda)*residual_loss.to(device) + Lambda*discrimination_loss
    return total_loss

# %%
loss_list = []
#y_list = []
for i, (x,y) in enumerate(test_dataloader):
    print(i, y)
    
    z = Variable(init.normal(torch.zeros(opt_test.batch_size,
                                     test_dataset.window_length, 
                                     test_dataset.n_feature),mean=0,std=0.1),requires_grad=True)
    #z = x
    z_optimizer = torch.optim.Adam([z],lr=opt_test.z_learning_rate)
    
    loss = None
    for j in range(opt_test.grad_descent_iterations): # set your interation range
        gen_fake = generator(z.cuda())
        loss = Anomaly_score(Variable(x).cuda(), gen_fake)
        loss.backward()
        z_optimizer.step()

    loss_list.append(loss) # Store the loss from the final iteration
    #y_list.append(y) # Store the corresponding anomaly label
    print('~~~~~~~~loss={},  y={} ~~~~~~~~~~'.format(loss, y))
    #break
# Out:
# 0 tensor([0.])
# /tmp/ipykernel_2808648/3731522451.py:6: UserWarning: nn.init.normal is now deprecated in favor of nn.init.normal_.
#   z = Variable(init.normal(torch.zeros(opt_test.batch_size,
# ~~~~~~~~loss=37.956966400146484,  y=tensor([0.]) ~~~~~~~~~~
# 1 tensor([0.])
# ~~~~~~~~loss=17.433454513549805,  y=tensor([0.]) ~~~~~~~~~~
# 2 tensor([0.])
# ~~~~~~~~loss=40.901458740234375,  y=tensor([0.]) ~~~~~~~~~~
# 3 tensor([0.])
# ~~~~~~~~loss=40.30805969238281,  y=tensor([0.]) ~~~~~~~~~~
# 4 tensor([0.])
# ~~~~~~~~loss=34.53292465209961,  y=tensor([0.]) ~~~~~~~~~~
# 5 tensor([0.])
# ~~~~~~~~loss=92.05533599853516,  y=tensor([0.]) ~~~~~~~~~~
# 6 tensor([0.])
# ~~~~~~~~loss=16.16425895690918,  y=tensor([0.]) ~~~~~~~~~~
# 7 tensor([0.])
# ~~~~~~~~loss=6.855546951293945,  y=tensor([0.]) ~~~~~~~~~~
# 8 tensor([0.])
# ~~~~~~~~loss=21.440216064453125,  y=tensor([0.]) ~~~~~~~~~~
# 9 tensor([0.])
# ~~~~~~~~loss=40.71297073364258,  y=tensor([0.]) ~~~~~~~~~~
# 10 tensor([0.])
# ~~~~~~~~loss=36.12028503417969,  y=tensor([0.]) ~~~~~~~~~~
# 11 tensor([0.])
# ~~~~~~~~loss=44.77901840209961,  y=tensor([0.]) ~~~~~~~~~~
# 12 tensor([0.])
# ~~~~~~~~loss=87.41345977783203,  y=tensor([0.]) ~~~~~~~~~~
# 13 tensor([0.])
# ~~~~~~~~loss=109.9010009765625,  y=tensor([0.]) ~~~~~~~~~~
# 14 tensor([0.])
# ~~~~~~~~loss=98.92134094238281,  y=tensor([0.]) ~~~~~~~~~~
# 15 tensor([0.])
# ~~~~~~~~loss=28.600040435791016,  y=tensor([0.]) ~~~~~~~~~~
# 16 tensor([0.])
# ~~~~~~~~loss=19.69387435913086,  y=tensor([0.]) ~~~~~~~~~~
# 17 tensor([0.])
# ~~~~~~~~loss=28.97054100036621,  y=tensor([0.]) ~~~~~~~~~~
# 18 tensor([0.])
# ~~~~~~~~loss=22.393112182617188,  y=tensor([0.]) ~~~~~~~~~~
# 19 tensor([0.])
# ~~~~~~~~loss=8.19642162322998,  y=tensor([0.]) ~~~~~~~~~~
# 20 tensor([0.])
# ~~~~~~~~loss=10.387909889221191,  y=tensor([0.]) ~~~~~~~~~~
# 21 tensor([0.])
# ~~~~~~~~loss=18.426307678222656,  y=tensor([0.]) ~~~~~~~~~~
# 22 tensor([0.])
# ~~~~~~~~loss=43.3293571472168,  y=tensor([0.]) ~~~~~~~~~~
# 23 tensor([0.])
# ~~~~~~~~loss=13.57071590423584,  y=tensor([0.]) ~~~~~~~~~~
# 24 tensor([0.])
# ~~~~~~~~loss=11.260297775268555,  y=tensor([0.]) ~~~~~~~~~~
# 25 tensor([0.])
# ~~~~~~~~loss=15.797385215759277,  y=tensor([0.]) ~~~~~~~~~~
# 26 tensor([0.])
# ~~~~~~~~loss=36.48871612548828,  y=tensor([0.]) ~~~~~~~~~~
# 27 tensor([0.])
# ~~~~~~~~loss=77.58528137207031,  y=tensor([0.]) ~~~~~~~~~~
# 28 tensor([0.])
# ~~~~~~~~loss=89.81602478027344,  y=tensor([0.]) ~~~~~~~~~~
# 29 tensor([0.])
# ~~~~~~~~loss=64.02715301513672,  y=tensor([0.]) ~~~~~~~~~~
# 30 tensor([0.])
# ~~~~~~~~loss=54.53740310668945,  y=tensor([0.]) ~~~~~~~~~~
# 31 tensor([0.])
# ~~~~~~~~loss=78.32775115966797,  y=tensor([0.]) ~~~~~~~~~~
# 32 tensor([0.])
# ~~~~~~~~loss=92.53079986572266,  y=tensor([0.]) ~~~~~~~~~~
# 33 tensor([0.])
# ~~~~~~~~loss=97.63874816894531,  y=tensor([0.]) ~~~~~~~~~~
# 34 tensor([0.])
# ~~~~~~~~loss=93.51126098632812,  y=tensor([0.]) ~~~~~~~~~~
# 35 tensor([1.])
# ~~~~~~~~loss=145.40972900390625,  y=tensor([1.]) ~~~~~~~~~~
# 36 tensor([1.])
# ~~~~~~~~loss=163.45318603515625,  y=tensor([1.]) ~~~~~~~~~~
# 37 tensor([1.])
# ~~~~~~~~loss=151.08595275878906,  y=tensor([1.]) ~~~~~~~~~~
# 38 tensor([1.])
# ~~~~~~~~loss=108.2871322631836,  y=tensor([1.]) ~~~~~~~~~~
# 39 tensor([1.])
# ~~~~~~~~loss=18.259986877441406,  y=tensor([1.]) ~~~~~~~~~~
# 40 tensor([1.])
# ~~~~~~~~loss=22.718534469604492,  y=tensor([1.]) ~~~~~~~~~~
# 41 tensor([1.])
# ~~~~~~~~loss=8.099458694458008,  y=tensor([1.]) ~~~~~~~~~~
# 42 tensor([1.])
# ~~~~~~~~loss=14.090109825134277,  y=tensor([1.]) ~~~~~~~~~~
# 43 tensor([1.])
# ~~~~~~~~loss=13.414268493652344,  y=tensor([1.]) ~~~~~~~~~~
# 44 tensor([1.])
# ~~~~~~~~loss=6.888038158416748,  y=tensor([1.]) ~~~~~~~~~~
# 45 tensor([0.])
# ~~~~~~~~loss=8.11894702911377,  y=tensor([0.]) ~~~~~~~~~~
# 46 tensor([0.])
# ~~~~~~~~loss=6.20497989654541,  y=tensor([0.]) ~~~~~~~~~~
# 47 tensor([0.])
# ~~~~~~~~loss=12.729406356811523,  y=tensor([0.]) ~~~~~~~~~~
# 48 tensor([0.])
# ~~~~~~~~loss=8.264394760131836,  y=tensor([0.]) ~~~~~~~~~~
# 49 tensor([0.])
# ~~~~~~~~loss=9.687299728393555,  y=tensor([0.]) ~~~~~~~~~~
# 50 tensor([0.])
# ~~~~~~~~loss=15.745943069458008,  y=tensor([0.]) ~~~~~~~~~~
# 51 tensor([0.])
# ~~~~~~~~loss=32.345458984375,  y=tensor([0.]) ~~~~~~~~~~
# 52 tensor([0.])
# ~~~~~~~~loss=38.658870697021484,  y=tensor([0.]) ~~~~~~~~~~
# 53 tensor([0.])
# ~~~~~~~~loss=39.28364181518555,  y=tensor([0.]) ~~~~~~~~~~
# 54 tensor([0.])
# ~~~~~~~~loss=38.77410125732422,  y=tensor([0.]) ~~~~~~~~~~
# 55 tensor([0.])
# ~~~~~~~~loss=35.212650299072266,  y=tensor([0.]) ~~~~~~~~~~
# 56 tensor([0.])
# ~~~~~~~~loss=27.81159019470215,  y=tensor([0.]) ~~~~~~~~~~
# 57 tensor([0.])
# ~~~~~~~~loss=29.928096771240234,  y=tensor([0.]) ~~~~~~~~~~
# 58 tensor([0.])
# ~~~~~~~~loss=26.500694274902344,  y=tensor([0.]) ~~~~~~~~~~
# 59 tensor([0.])
# ~~~~~~~~loss=28.91773796081543,  y=tensor([0.]) ~~~~~~~~~~
# 60 tensor([0.])
# ~~~~~~~~loss=27.430837631225586,  y=tensor([0.]) ~~~~~~~~~~
# 61 tensor([1.])
# ~~~~~~~~loss=27.563304901123047,  y=tensor([1.]) ~~~~~~~~~~
# 62 tensor([1.])
# ~~~~~~~~loss=50.62395477294922,  y=tensor([1.]) ~~~~~~~~~~
# 63 tensor([1.])
# ~~~~~~~~loss=118.8757095336914,  y=tensor([1.]) ~~~~~~~~~~
# 64 tensor([1.])
# ~~~~~~~~loss=158.7116241455078,  y=tensor([1.]) ~~~~~~~~~~
# 65 tensor([1.])
# ~~~~~~~~loss=173.79150390625,  y=tensor([1.]) ~~~~~~~~~~
# 66 tensor([1.])
# ~~~~~~~~loss=175.4189910888672,  y=tensor([1.]) ~~~~~~~~~~
# 67 tensor([1.])
# ~~~~~~~~loss=31.16668128967285,  y=tensor([1.]) ~~~~~~~~~~
# 68 tensor([1.])
# ~~~~~~~~loss=54.637115478515625,  y=tensor([1.]) ~~~~~~~~~~
# 69 tensor([1.])
# ~~~~~~~~loss=24.627349853515625,  y=tensor([1.]) ~~~~~~~~~~
# 70 tensor([1.])
# ~~~~~~~~loss=7.206769943237305,  y=tensor([1.]) ~~~~~~~~~~
# 71 tensor([1.])
# ~~~~~~~~loss=12.965189933776855,  y=tensor([1.]) ~~~~~~~~~~
# 72 tensor([0.])
# ~~~~~~~~loss=40.96458435058594,  y=tensor([0.]) ~~~~~~~~~~
# 73 tensor([0.])
# ~~~~~~~~loss=41.11574935913086,  y=tensor([0.]) ~~~~~~~~~~
# 74 tensor([0.])
# ~~~~~~~~loss=43.96882629394531,  y=tensor([0.]) ~~~~~~~~~~
# 75 tensor([0.])
# ~~~~~~~~loss=44.905391693115234,  y=tensor([0.]) ~~~~~~~~~~
# 76 tensor([0.])
# ~~~~~~~~loss=41.57679748535156,  y=tensor([0.]) ~~~~~~~~~~
# 77 tensor([0.])
# ~~~~~~~~loss=39.96474075317383,  y=tensor([0.]) ~~~~~~~~~~
# 78 tensor([0.])
# ~~~~~~~~loss=42.551002502441406,  y=tensor([0.]) ~~~~~~~~~~
# 79 tensor([0.])
# ~~~~~~~~loss=45.34504318237305,  y=tensor([0.]) ~~~~~~~~~~
# 80 tensor([0.])
# ~~~~~~~~loss=41.18382263183594,  y=tensor([0.]) ~~~~~~~~~~
# 81 tensor([0.])
# ~~~~~~~~loss=32.970436096191406,  y=tensor([0.]) ~~~~~~~~~~
# 82 tensor([0.])
# ~~~~~~~~loss=15.476378440856934,  y=tensor([0.]) ~~~~~~~~~~
# 83 tensor([0.])
# ~~~~~~~~loss=15.77798080444336,  y=tensor([0.]) ~~~~~~~~~~
# 84 tensor([0.])
# ~~~~~~~~loss=27.5111141204834,  y=tensor([0.]) ~~~~~~~~~~
# 85 tensor([0.])
# ~~~~~~~~loss=19.422948837280273,  y=tensor([0.]) ~~~~~~~~~~
# 86 tensor([0.])
# ~~~~~~~~loss=27.797861099243164,  y=tensor([0.]) ~~~~~~~~~~
# 87 tensor([0.])
# ~~~~~~~~loss=16.199636459350586,  y=tensor([0.]) ~~~~~~~~~~
# 88 tensor([0.])
# ~~~~~~~~loss=12.958972930908203,  y=tensor([0.]) ~~~~~~~~~~
# 89 tensor([0.])
# ~~~~~~~~loss=12.560943603515625,  y=tensor([0.]) ~~~~~~~~~~
# 90 tensor([0.])
# ~~~~~~~~loss=10.025823593139648,  y=tensor([0.]) ~~~~~~~~~~
# 91 tensor([0.])
# ~~~~~~~~loss=6.13328218460083,  y=tensor([0.]) ~~~~~~~~~~
# 92 tensor([0.])
# ~~~~~~~~loss=18.615222930908203,  y=tensor([0.]) ~~~~~~~~~~
# 93 tensor([0.])
# ~~~~~~~~loss=11.395537376403809,  y=tensor([0.]) ~~~~~~~~~~
# 94 tensor([0.])
# ~~~~~~~~loss=15.087014198303223,  y=tensor([0.]) ~~~~~~~~~~
# 95 tensor([0.])
# ~~~~~~~~loss=16.962194442749023,  y=tensor([0.]) ~~~~~~~~~~
# 96 tensor([0.])
# ~~~~~~~~loss=19.2420654296875,  y=tensor([0.]) ~~~~~~~~~~
# 97 tensor([0.])
# ~~~~~~~~loss=16.578365325927734,  y=tensor([0.]) ~~~~~~~~~~
# 98 tensor([0.])
# ~~~~~~~~loss=32.50646209716797,  y=tensor([0.]) ~~~~~~~~~~
# 99 tensor([0.])
# ~~~~~~~~loss=48.44667434692383,  y=tensor([0.]) ~~~~~~~~~~
# 100 tensor([0.])
# ~~~~~~~~loss=11.7794189453125,  y=tensor([0.]) ~~~~~~~~~~
# 101 tensor([0.])
# ~~~~~~~~loss=8.501912117004395,  y=tensor([0.]) ~~~~~~~~~~
# 102 tensor([0.])
# ~~~~~~~~loss=13.80844497680664,  y=tensor([0.]) ~~~~~~~~~~
# 103 tensor([0.])
# ~~~~~~~~loss=34.14763641357422,  y=tensor([0.]) ~~~~~~~~~~
# 104 tensor([0.])
# ~~~~~~~~loss=61.24232482910156,  y=tensor([0.]) ~~~~~~~~~~
# 105 tensor([0.])
# ~~~~~~~~loss=63.58275604248047,  y=tensor([0.]) ~~~~~~~~~~
# 106 tensor([0.])
# ~~~~~~~~loss=14.304433822631836,  y=tensor([0.]) ~~~~~~~~~~
# 107 tensor([0.])
# ~~~~~~~~loss=13.717151641845703,  y=tensor([0.]) ~~~~~~~~~~
# 108 tensor([0.])
# ~~~~~~~~loss=14.473189353942871,  y=tensor([0.]) ~~~~~~~~~~
# 109 tensor([0.])
# ~~~~~~~~loss=12.77701473236084,  y=tensor([0.]) ~~~~~~~~~~
# 110 tensor([0.])
# ~~~~~~~~loss=7.261035919189453,  y=tensor([0.]) ~~~~~~~~~~
# 111 tensor([0.])
# ~~~~~~~~loss=27.461868286132812,  y=tensor([0.]) ~~~~~~~~~~
# 112 tensor([0.])
# ~~~~~~~~loss=20.629058837890625,  y=tensor([0.]) ~~~~~~~~~~
# 113 tensor([0.])
# ~~~~~~~~loss=32.51474380493164,  y=tensor([0.]) ~~~~~~~~~~
# 114 tensor([0.])
# ~~~~~~~~loss=49.980186462402344,  y=tensor([0.]) ~~~~~~~~~~
# 115 tensor([0.])
# ~~~~~~~~loss=25.59951400756836,  y=tensor([0.]) ~~~~~~~~~~
# 116 tensor([0.])
# ~~~~~~~~loss=6.036369323730469,  y=tensor([0.]) ~~~~~~~~~~
# 117 tensor([0.])
# ~~~~~~~~loss=9.539435386657715,  y=tensor([0.]) ~~~~~~~~~~
# 118 tensor([0.])
# ~~~~~~~~loss=9.108779907226562,  y=tensor([0.]) ~~~~~~~~~~
# 119 tensor([0.])
# ~~~~~~~~loss=63.068443298339844,  y=tensor([0.]) ~~~~~~~~~~
# 120 tensor([0.])
# ~~~~~~~~loss=57.227684020996094,  y=tensor([0.]) ~~~~~~~~~~
# 121 tensor([0.])
# ~~~~~~~~loss=73.32839965820312,  y=tensor([0.]) ~~~~~~~~~~
# 122 tensor([0.])
# ~~~~~~~~loss=9.566839218139648,  y=tensor([0.]) ~~~~~~~~~~
# 123 tensor([0.])
# ~~~~~~~~loss=23.728849411010742,  y=tensor([0.]) ~~~~~~~~~~
# 124 tensor([0.])
# ~~~~~~~~loss=46.17453384399414,  y=tensor([0.]) ~~~~~~~~~~
# 125 tensor([0.])
# ~~~~~~~~loss=30.911344528198242,  y=tensor([0.]) ~~~~~~~~~~
# 126 tensor([0.])
# ~~~~~~~~loss=10.990880966186523,  y=tensor([0.]) ~~~~~~~~~~
# 127 tensor([0.])
# ~~~~~~~~loss=18.801179885864258,  y=tensor([0.]) ~~~~~~~~~~
# 128 tensor([0.])
# ~~~~~~~~loss=41.29230499267578,  y=tensor([0.]) ~~~~~~~~~~
# 129 tensor([0.])
# ~~~~~~~~loss=19.959760665893555,  y=tensor([0.]) ~~~~~~~~~~
# 130 tensor([0.])
# ~~~~~~~~loss=21.365808486938477,  y=tensor([0.]) ~~~~~~~~~~
# 131 tensor([0.])
# ~~~~~~~~loss=7.289661884307861,  y=tensor([0.]) ~~~~~~~~~~
# 132 tensor([0.])
# ~~~~~~~~loss=19.934946060180664,  y=tensor([0.]) ~~~~~~~~~~
# 133 tensor([0.])
# ~~~~~~~~loss=7.797412395477295,  y=tensor([0.]) ~~~~~~~~~~
# 134 tensor([0.])
# ~~~~~~~~loss=7.18220853805542,  y=tensor([0.]) ~~~~~~~~~~
# 135 tensor([0.])
# ~~~~~~~~loss=4.685418128967285,  y=tensor([0.]) ~~~~~~~~~~
# 136 tensor([0.])
# ~~~~~~~~loss=5.030570983886719,  y=tensor([0.]) ~~~~~~~~~~
# 137 tensor([0.])
# ~~~~~~~~loss=4.027280807495117,  y=tensor([0.]) ~~~~~~~~~~
# 138 tensor([0.])
# ~~~~~~~~loss=9.082846641540527,  y=tensor([0.]) ~~~~~~~~~~
# 139 tensor([0.])
# ~~~~~~~~loss=12.791939735412598,  y=tensor([0.]) ~~~~~~~~~~
# 140 tensor([0.])
# ~~~~~~~~loss=4.540877819061279,  y=tensor([0.]) ~~~~~~~~~~
# 141 tensor([0.])
# ~~~~~~~~loss=3.478027105331421,  y=tensor([0.]) ~~~~~~~~~~
# 142 tensor([0.])
# ~~~~~~~~loss=20.088394165039062,  y=tensor([0.]) ~~~~~~~~~~
# 143 tensor([0.])
# ~~~~~~~~loss=37.327667236328125,  y=tensor([0.]) ~~~~~~~~~~
# 144 tensor([0.])
# ~~~~~~~~loss=29.032007217407227,  y=tensor([0.]) ~~~~~~~~~~
# 145 tensor([0.])
# ~~~~~~~~loss=10.17164421081543,  y=tensor([0.]) ~~~~~~~~~~
# 146 tensor([0.])
# ~~~~~~~~loss=36.065860748291016,  y=tensor([0.]) ~~~~~~~~~~
# 147 tensor([0.])
# ~~~~~~~~loss=24.116870880126953,  y=tensor([0.]) ~~~~~~~~~~
# 148 tensor([0.])
# ~~~~~~~~loss=19.36490249633789,  y=tensor([0.]) ~~~~~~~~~~
# 149 tensor([0.])
# ~~~~~~~~loss=13.769906044006348,  y=tensor([0.]) ~~~~~~~~~~
# 150 tensor([0.])
# ~~~~~~~~loss=10.044502258300781,  y=tensor([0.]) ~~~~~~~~~~
# 151 tensor([0.])
# ~~~~~~~~loss=7.907431125640869,  y=tensor([0.]) ~~~~~~~~~~
# 152 tensor([0.])
# ~~~~~~~~loss=5.523581504821777,  y=tensor([0.]) ~~~~~~~~~~
# 153 tensor([0.])
# ~~~~~~~~loss=2.217301845550537,  y=tensor([0.]) ~~~~~~~~~~
# 154 tensor([0.])
# ~~~~~~~~loss=4.5099945068359375,  y=tensor([0.]) ~~~~~~~~~~
# 155 tensor([0.])
# ~~~~~~~~loss=4.355200290679932,  y=tensor([0.]) ~~~~~~~~~~
# 156 tensor([0.])
# ~~~~~~~~loss=8.406465530395508,  y=tensor([0.]) ~~~~~~~~~~
# 157 tensor([0.])
# ~~~~~~~~loss=8.227652549743652,  y=tensor([0.]) ~~~~~~~~~~
# 158 tensor([0.])
# ~~~~~~~~loss=10.554258346557617,  y=tensor([0.]) ~~~~~~~~~~
# 159 tensor([0.])
# ~~~~~~~~loss=24.77891731262207,  y=tensor([0.]) ~~~~~~~~~~
# 160 tensor([0.])
# ~~~~~~~~loss=30.62937355041504,  y=tensor([0.]) ~~~~~~~~~~
# 161 tensor([0.])
# ~~~~~~~~loss=93.1302490234375,  y=tensor([0.]) ~~~~~~~~~~
# 162 tensor([0.])
# ~~~~~~~~loss=102.50946044921875,  y=tensor([0.]) ~~~~~~~~~~
# 163 tensor([0.])
# ~~~~~~~~loss=46.95911407470703,  y=tensor([0.]) ~~~~~~~~~~
# 164 tensor([0.])
# ~~~~~~~~loss=36.19400405883789,  y=tensor([0.]) ~~~~~~~~~~
# 165 tensor([0.])
# ~~~~~~~~loss=34.14886474609375,  y=tensor([0.]) ~~~~~~~~~~
# 166 tensor([0.])
# ~~~~~~~~loss=34.692481994628906,  y=tensor([0.]) ~~~~~~~~~~
# 167 tensor([0.])
# ~~~~~~~~loss=46.26538848876953,  y=tensor([0.]) ~~~~~~~~~~
# 168 tensor([0.])
# ~~~~~~~~loss=8.793129920959473,  y=tensor([0.]) ~~~~~~~~~~
# 169 tensor([0.])
# ~~~~~~~~loss=10.599766731262207,  y=tensor([0.]) ~~~~~~~~~~
# 170 tensor([0.])
# ~~~~~~~~loss=16.805370330810547,  y=tensor([0.]) ~~~~~~~~~~
# 171 tensor([0.])
# ~~~~~~~~loss=21.23126792907715,  y=tensor([0.]) ~~~~~~~~~~
# 172 tensor([0.])
# ~~~~~~~~loss=19.30000877380371,  y=tensor([0.]) ~~~~~~~~~~
# 173 tensor([0.])
# ~~~~~~~~loss=19.331037521362305,  y=tensor([0.]) ~~~~~~~~~~
# 174 tensor([0.])
# ~~~~~~~~loss=19.6129207611084,  y=tensor([0.]) ~~~~~~~~~~
# 175 tensor([0.])
# ~~~~~~~~loss=23.10512924194336,  y=tensor([0.]) ~~~~~~~~~~
# 176 tensor([0.])
# ~~~~~~~~loss=21.056209564208984,  y=tensor([0.]) ~~~~~~~~~~
# 177 tensor([0.])
# ~~~~~~~~loss=11.906618118286133,  y=tensor([0.]) ~~~~~~~~~~
# 178 tensor([0.])
# ~~~~~~~~loss=24.299339294433594,  y=tensor([0.]) ~~~~~~~~~~
# 179 tensor([0.])
# ~~~~~~~~loss=9.542047500610352,  y=tensor([0.]) ~~~~~~~~~~
# 180 tensor([0.])
# ~~~~~~~~loss=4.927541732788086,  y=tensor([0.]) ~~~~~~~~~~
# 181 tensor([0.])
# ~~~~~~~~loss=23.247364044189453,  y=tensor([0.]) ~~~~~~~~~~
# 182 tensor([0.])
# ~~~~~~~~loss=25.558204650878906,  y=tensor([0.]) ~~~~~~~~~~
# 183 tensor([0.])
# ~~~~~~~~loss=19.52297592163086,  y=tensor([0.]) ~~~~~~~~~~
# 184 tensor([0.])
# ~~~~~~~~loss=11.847000122070312,  y=tensor([0.]) ~~~~~~~~~~
# 185 tensor([0.])
# ~~~~~~~~loss=4.133448123931885,  y=tensor([0.]) ~~~~~~~~~~
# 186 tensor([0.])
# ~~~~~~~~loss=7.907011032104492,  y=tensor([0.]) ~~~~~~~~~~
# 187 tensor([0.])
# ~~~~~~~~loss=13.541857719421387,  y=tensor([0.]) ~~~~~~~~~~
# 188 tensor([0.])
# ~~~~~~~~loss=14.301714897155762,  y=tensor([0.]) ~~~~~~~~~~
# 189 tensor([0.])
# ~~~~~~~~loss=8.245223045349121,  y=tensor([0.]) ~~~~~~~~~~
# 190 tensor([0.])
# ~~~~~~~~loss=8.876133918762207,  y=tensor([0.]) ~~~~~~~~~~
# 191 tensor([0.])
# ~~~~~~~~loss=17.830556869506836,  y=tensor([0.]) ~~~~~~~~~~
# 192 tensor([0.])
# ~~~~~~~~loss=26.735919952392578,  y=tensor([0.]) ~~~~~~~~~~
# 193 tensor([0.])
# ~~~~~~~~loss=34.88235855102539,  y=tensor([0.]) ~~~~~~~~~~
# 194 tensor([0.])
# ~~~~~~~~loss=25.938493728637695,  y=tensor([0.]) ~~~~~~~~~~
# 195 tensor([0.])
# ~~~~~~~~loss=16.044240951538086,  y=tensor([0.]) ~~~~~~~~~~
# 196 tensor([0.])
# ~~~~~~~~loss=8.372244834899902,  y=tensor([0.]) ~~~~~~~~~~
# 197 tensor([0.])
# ~~~~~~~~loss=17.361072540283203,  y=tensor([0.]) ~~~~~~~~~~
# 198 tensor([0.])
# ~~~~~~~~loss=18.69130516052246,  y=tensor([0.]) ~~~~~~~~~~
# 199 tensor([0.])
# ~~~~~~~~loss=54.02735137939453,  y=tensor([0.]) ~~~~~~~~~~
# 200 tensor([0.])
# ~~~~~~~~loss=89.4887924194336,  y=tensor([0.]) ~~~~~~~~~~
# 201 tensor([0.])
# ~~~~~~~~loss=97.48658752441406,  y=tensor([0.]) ~~~~~~~~~~
# 202 tensor([0.])
# ~~~~~~~~loss=11.64015007019043,  y=tensor([0.]) ~~~~~~~~~~
# 203 tensor([0.])
# ~~~~~~~~loss=3.5072827339172363,  y=tensor([0.]) ~~~~~~~~~~
# 204 tensor([0.])
# ~~~~~~~~loss=11.56241512298584,  y=tensor([0.]) ~~~~~~~~~~
# 205 tensor([0.])
# ~~~~~~~~loss=28.21878433227539,  y=tensor([0.]) ~~~~~~~~~~
# 206 tensor([0.])
# ~~~~~~~~loss=11.798189163208008,  y=tensor([0.]) ~~~~~~~~~~
# 207 tensor([0.])
# ~~~~~~~~loss=28.71533203125,  y=tensor([0.]) ~~~~~~~~~~
# 208 tensor([0.])
# ~~~~~~~~loss=22.592103958129883,  y=tensor([0.]) ~~~~~~~~~~
# 209 tensor([0.])
# ~~~~~~~~loss=4.709442138671875,  y=tensor([0.]) ~~~~~~~~~~
# 210 tensor([0.])
# ~~~~~~~~loss=3.775155544281006,  y=tensor([0.]) ~~~~~~~~~~
# 211 tensor([0.])
# ~~~~~~~~loss=5.1268310546875,  y=tensor([0.]) ~~~~~~~~~~
# 212 tensor([0.])
# ~~~~~~~~loss=8.886168479919434,  y=tensor([0.]) ~~~~~~~~~~
# 213 tensor([0.])
# ~~~~~~~~loss=28.326358795166016,  y=tensor([0.]) ~~~~~~~~~~
# 214 tensor([0.])
# ~~~~~~~~loss=77.34876251220703,  y=tensor([0.]) ~~~~~~~~~~
# 215 tensor([0.])
# ~~~~~~~~loss=7.597165107727051,  y=tensor([0.]) ~~~~~~~~~~
# 216 tensor([0.])
# ~~~~~~~~loss=8.61376667022705,  y=tensor([0.]) ~~~~~~~~~~
# 217 tensor([0.])
# ~~~~~~~~loss=12.66695785522461,  y=tensor([0.]) ~~~~~~~~~~
# 218 tensor([0.])
# ~~~~~~~~loss=25.41431427001953,  y=tensor([0.]) ~~~~~~~~~~
# 219 tensor([0.])
# ~~~~~~~~loss=28.41753578186035,  y=tensor([0.]) ~~~~~~~~~~
# 220 tensor([0.])
# ~~~~~~~~loss=16.922008514404297,  y=tensor([0.]) ~~~~~~~~~~
# 221 tensor([0.])
# ~~~~~~~~loss=7.526750564575195,  y=tensor([0.]) ~~~~~~~~~~
# 222 tensor([0.])
# ~~~~~~~~loss=16.805452346801758,  y=tensor([0.]) ~~~~~~~~~~
# 223 tensor([0.])
# ~~~~~~~~loss=29.736494064331055,  y=tensor([0.]) ~~~~~~~~~~
# 224 tensor([0.])
# ~~~~~~~~loss=46.724491119384766,  y=tensor([0.]) ~~~~~~~~~~
# 225 tensor([0.])
# ~~~~~~~~loss=4.514781475067139,  y=tensor([0.]) ~~~~~~~~~~
# 226 tensor([0.])
# ~~~~~~~~loss=7.4646525382995605,  y=tensor([0.]) ~~~~~~~~~~
# 227 tensor([0.])
# ~~~~~~~~loss=6.114950656890869,  y=tensor([0.]) ~~~~~~~~~~
# 228 tensor([0.])
# ~~~~~~~~loss=6.096789836883545,  y=tensor([0.]) ~~~~~~~~~~
# 229 tensor([0.])
# ~~~~~~~~loss=8.134636878967285,  y=tensor([0.]) ~~~~~~~~~~
# 230 tensor([0.])
# ~~~~~~~~loss=4.736640930175781,  y=tensor([0.]) ~~~~~~~~~~
# 231 tensor([0.])
# ~~~~~~~~loss=6.030679225921631,  y=tensor([0.]) ~~~~~~~~~~
# 232 tensor([0.])
# ~~~~~~~~loss=6.057857990264893,  y=tensor([0.]) ~~~~~~~~~~
# 233 tensor([0.])
# ~~~~~~~~loss=36.47739791870117,  y=tensor([0.]) ~~~~~~~~~~
# 234 tensor([0.])
# ~~~~~~~~loss=64.2061767578125,  y=tensor([0.]) ~~~~~~~~~~
# 235 tensor([0.])
# ~~~~~~~~loss=6.161894798278809,  y=tensor([0.]) ~~~~~~~~~~
# 236 tensor([0.])
# ~~~~~~~~loss=31.555721282958984,  y=tensor([0.]) ~~~~~~~~~~
# 237 tensor([0.])
# ~~~~~~~~loss=17.22740936279297,  y=tensor([0.]) ~~~~~~~~~~
# 238 tensor([0.])
# ~~~~~~~~loss=15.518160820007324,  y=tensor([0.]) ~~~~~~~~~~
# 239 tensor([0.])
# ~~~~~~~~loss=21.622459411621094,  y=tensor([0.]) ~~~~~~~~~~
# 240 tensor([0.])
# ~~~~~~~~loss=22.984539031982422,  y=tensor([0.]) ~~~~~~~~~~
# 241 tensor([0.])
# ~~~~~~~~loss=41.73451614379883,  y=tensor([0.]) ~~~~~~~~~~
# 242 tensor([0.])
# ~~~~~~~~loss=56.323917388916016,  y=tensor([0.]) ~~~~~~~~~~
# 243 tensor([0.])
# ~~~~~~~~loss=66.26299285888672,  y=tensor([0.]) ~~~~~~~~~~
# 244 tensor([0.])
# ~~~~~~~~loss=26.59375,  y=tensor([0.]) ~~~~~~~~~~
# 245 tensor([0.])
# ~~~~~~~~loss=7.513304233551025,  y=tensor([0.]) ~~~~~~~~~~
# 246 tensor([0.])
# ~~~~~~~~loss=4.693009853363037,  y=tensor([0.]) ~~~~~~~~~~
# 247 tensor([0.])
# ~~~~~~~~loss=11.452950477600098,  y=tensor([0.]) ~~~~~~~~~~
# 248 tensor([0.])
# ~~~~~~~~loss=41.127723693847656,  y=tensor([0.]) ~~~~~~~~~~
# 249 tensor([0.])
# ~~~~~~~~loss=14.541873931884766,  y=tensor([0.]) ~~~~~~~~~~
# 250 tensor([0.])
# ~~~~~~~~loss=7.904491424560547,  y=tensor([0.]) ~~~~~~~~~~
# 251 tensor([0.])
# ~~~~~~~~loss=7.082119941711426,  y=tensor([0.]) ~~~~~~~~~~
# 252 tensor([0.])
# ~~~~~~~~loss=106.59234619140625,  y=tensor([0.]) ~~~~~~~~~~
# 253 tensor([0.])
# ~~~~~~~~loss=35.070064544677734,  y=tensor([0.]) ~~~~~~~~~~
# 254 tensor([0.])
# ~~~~~~~~loss=41.811676025390625,  y=tensor([0.]) ~~~~~~~~~~
# 255 tensor([0.])
# ~~~~~~~~loss=39.359737396240234,  y=tensor([0.]) ~~~~~~~~~~
# 256 tensor([0.])
# ~~~~~~~~loss=44.81900405883789,  y=tensor([0.]) ~~~~~~~~~~
# 257 tensor([0.])
# ~~~~~~~~loss=46.799320220947266,  y=tensor([0.]) ~~~~~~~~~~
# 258 tensor([0.])
# ~~~~~~~~loss=45.03903579711914,  y=tensor([0.]) ~~~~~~~~~~
# 259 tensor([0.])
# ~~~~~~~~loss=27.90041160583496,  y=tensor([0.]) ~~~~~~~~~~
# 260 tensor([0.])
# ~~~~~~~~loss=19.907819747924805,  y=tensor([0.]) ~~~~~~~~~~
# 261 tensor([0.])
# ~~~~~~~~loss=16.32570457458496,  y=tensor([0.]) ~~~~~~~~~~
# 262 tensor([0.])
# ~~~~~~~~loss=15.898661613464355,  y=tensor([0.]) ~~~~~~~~~~
# 263 tensor([0.])
# ~~~~~~~~loss=14.981931686401367,  y=tensor([0.]) ~~~~~~~~~~
# 264 tensor([0.])
# ~~~~~~~~loss=14.282928466796875,  y=tensor([0.]) ~~~~~~~~~~
# 265 tensor([0.])
# ~~~~~~~~loss=19.346515655517578,  y=tensor([0.]) ~~~~~~~~~~
# 266 tensor([0.])
# ~~~~~~~~loss=36.146915435791016,  y=tensor([0.]) ~~~~~~~~~~
# 267 tensor([1.])
# ~~~~~~~~loss=99.91192626953125,  y=tensor([1.]) ~~~~~~~~~~
# 268 tensor([1.])
# ~~~~~~~~loss=97.50000762939453,  y=tensor([1.]) ~~~~~~~~~~
# 269 tensor([1.])
# ~~~~~~~~loss=114.52259063720703,  y=tensor([1.]) ~~~~~~~~~~
# 270 tensor([1.])
# ~~~~~~~~loss=108.57512664794922,  y=tensor([1.]) ~~~~~~~~~~
# 271 tensor([1.])
# ~~~~~~~~loss=116.7536849975586,  y=tensor([1.]) ~~~~~~~~~~
# 272 tensor([1.])
# ~~~~~~~~loss=147.75320434570312,  y=tensor([1.]) ~~~~~~~~~~
# 273 tensor([1.])
# ~~~~~~~~loss=123.17188262939453,  y=tensor([1.]) ~~~~~~~~~~
# 274 tensor([1.])
# ~~~~~~~~loss=71.74884033203125,  y=tensor([1.]) ~~~~~~~~~~
# 275 tensor([1.])
# ~~~~~~~~loss=76.2403793334961,  y=tensor([1.]) ~~~~~~~~~~
# 276 tensor([1.])
# ~~~~~~~~loss=90.26067352294922,  y=tensor([1.]) ~~~~~~~~~~
# 277 tensor([1.])
# ~~~~~~~~loss=146.71177673339844,  y=tensor([1.]) ~~~~~~~~~~
# 278 tensor([0.])
# ~~~~~~~~loss=57.044795989990234,  y=tensor([0.]) ~~~~~~~~~~
# 279 tensor([0.])
# ~~~~~~~~loss=41.8708381652832,  y=tensor([0.]) ~~~~~~~~~~
# 280 tensor([0.])
# ~~~~~~~~loss=84.68668365478516,  y=tensor([0.]) ~~~~~~~~~~
# 281 tensor([0.])
# ~~~~~~~~loss=83.56523895263672,  y=tensor([0.]) ~~~~~~~~~~
# 282 tensor([0.])
# ~~~~~~~~loss=147.51785278320312,  y=tensor([0.]) ~~~~~~~~~~
# 283 tensor([0.])
# ~~~~~~~~loss=131.33969116210938,  y=tensor([0.]) ~~~~~~~~~~
# 284 tensor([0.])
# ~~~~~~~~loss=55.94700241088867,  y=tensor([0.]) ~~~~~~~~~~
# 285 tensor([0.])
# ~~~~~~~~loss=34.52191162109375,  y=tensor([0.]) ~~~~~~~~~~
# 286 tensor([0.])
# ~~~~~~~~loss=92.86012268066406,  y=tensor([0.]) ~~~~~~~~~~
# 287 tensor([0.])
# ~~~~~~~~loss=34.012054443359375,  y=tensor([0.]) ~~~~~~~~~~
# 288 tensor([0.])
# ~~~~~~~~loss=6.797228813171387,  y=tensor([0.]) ~~~~~~~~~~
# 289 tensor([0.])
# ~~~~~~~~loss=4.5329742431640625,  y=tensor([0.]) ~~~~~~~~~~
# 290 tensor([0.])
# ~~~~~~~~loss=3.7903947830200195,  y=tensor([0.]) ~~~~~~~~~~
# 291 tensor([0.])
# ~~~~~~~~loss=18.340715408325195,  y=tensor([0.]) ~~~~~~~~~~
# 292 tensor([0.])
# ~~~~~~~~loss=5.8782758712768555,  y=tensor([0.]) ~~~~~~~~~~
# 293 tensor([0.])
# ~~~~~~~~loss=6.36489725112915,  y=tensor([0.]) ~~~~~~~~~~
# 294 tensor([0.])
# ~~~~~~~~loss=3.926011562347412,  y=tensor([0.]) ~~~~~~~~~~
# 295 tensor([0.])
# ~~~~~~~~loss=23.20956802368164,  y=tensor([0.]) ~~~~~~~~~~
# 296 tensor([0.])
# ~~~~~~~~loss=12.157549858093262,  y=tensor([0.]) ~~~~~~~~~~
# 297 tensor([0.])
# ~~~~~~~~loss=5.493294715881348,  y=tensor([0.]) ~~~~~~~~~~
# 298 tensor([0.])
# ~~~~~~~~loss=69.337890625,  y=tensor([0.]) ~~~~~~~~~~
# 299 tensor([0.])
# ~~~~~~~~loss=144.83425903320312,  y=tensor([0.]) ~~~~~~~~~~
# 300 tensor([0.])
# ~~~~~~~~loss=133.57652282714844,  y=tensor([0.]) ~~~~~~~~~~
# 301 tensor([0.])
# ~~~~~~~~loss=26.172988891601562,  y=tensor([0.]) ~~~~~~~~~~
# 302 tensor([0.])
# ~~~~~~~~loss=26.3294734954834,  y=tensor([0.]) ~~~~~~~~~~
# 303 tensor([0.])
# ~~~~~~~~loss=21.954875946044922,  y=tensor([0.]) ~~~~~~~~~~
# 304 tensor([0.])
# ~~~~~~~~loss=28.458744049072266,  y=tensor([0.]) ~~~~~~~~~~
# 305 tensor([0.])
# ~~~~~~~~loss=26.87702178955078,  y=tensor([0.]) ~~~~~~~~~~
# 306 tensor([0.])
# ~~~~~~~~loss=18.43206214904785,  y=tensor([0.]) ~~~~~~~~~~
# 307 tensor([0.])
# ~~~~~~~~loss=6.236310005187988,  y=tensor([0.]) ~~~~~~~~~~
# 308 tensor([0.])
# ~~~~~~~~loss=56.027400970458984,  y=tensor([0.]) ~~~~~~~~~~
# 309 tensor([0.])
# ~~~~~~~~loss=18.37623405456543,  y=tensor([0.]) ~~~~~~~~~~
# 310 tensor([0.])
# ~~~~~~~~loss=23.54990005493164,  y=tensor([0.]) ~~~~~~~~~~
# 311 tensor([0.])
# ~~~~~~~~loss=8.804671287536621,  y=tensor([0.]) ~~~~~~~~~~
# 312 tensor([0.])
# ~~~~~~~~loss=5.633450031280518,  y=tensor([0.]) ~~~~~~~~~~
# 313 tensor([0.])
# ~~~~~~~~loss=2.6342413425445557,  y=tensor([0.]) ~~~~~~~~~~
# 314 tensor([0.])
# ~~~~~~~~loss=5.550340175628662,  y=tensor([0.]) ~~~~~~~~~~
# 315 tensor([0.])
# ~~~~~~~~loss=13.027231216430664,  y=tensor([0.]) ~~~~~~~~~~
# 316 tensor([0.])
# ~~~~~~~~loss=31.922306060791016,  y=tensor([0.]) ~~~~~~~~~~
# 317 tensor([0.])
# ~~~~~~~~loss=22.407081604003906,  y=tensor([0.]) ~~~~~~~~~~
# 318 tensor([0.])
# ~~~~~~~~loss=4.643699645996094,  y=tensor([0.]) ~~~~~~~~~~
# 319 tensor([0.])
# ~~~~~~~~loss=98.91980743408203,  y=tensor([0.]) ~~~~~~~~~~
# 320 tensor([1.])
# ~~~~~~~~loss=132.71665954589844,  y=tensor([1.]) ~~~~~~~~~~
# 321 tensor([1.])
# ~~~~~~~~loss=157.967529296875,  y=tensor([1.]) ~~~~~~~~~~
# 322 tensor([1.])
# ~~~~~~~~loss=183.78857421875,  y=tensor([1.]) ~~~~~~~~~~
# 323 tensor([1.])
# ~~~~~~~~loss=209.49205017089844,  y=tensor([1.]) ~~~~~~~~~~
# 324 tensor([1.])
# ~~~~~~~~loss=234.59375,  y=tensor([1.]) ~~~~~~~~~~
# 325 tensor([1.])
# ~~~~~~~~loss=244.8572540283203,  y=tensor([1.]) ~~~~~~~~~~
# 326 tensor([1.])
# ~~~~~~~~loss=231.06692504882812,  y=tensor([1.]) ~~~~~~~~~~
# 327 tensor([1.])
# ~~~~~~~~loss=226.08428955078125,  y=tensor([1.]) ~~~~~~~~~~
# 328 tensor([1.])
# ~~~~~~~~loss=236.26922607421875,  y=tensor([1.]) ~~~~~~~~~~
# 329 tensor([1.])
# ~~~~~~~~loss=144.49215698242188,  y=tensor([1.]) ~~~~~~~~~~
# 330 tensor([0.])
# ~~~~~~~~loss=5.358719825744629,  y=tensor([0.]) ~~~~~~~~~~
# 331 tensor([0.])
# ~~~~~~~~loss=2.4685580730438232,  y=tensor([0.]) ~~~~~~~~~~
# 332 tensor([0.])
# ~~~~~~~~loss=18.663122177124023,  y=tensor([0.]) ~~~~~~~~~~
# 333 tensor([0.])
# ~~~~~~~~loss=28.86274528503418,  y=tensor([0.]) ~~~~~~~~~~
# 334 tensor([0.])
# ~~~~~~~~loss=18.03155517578125,  y=tensor([0.]) ~~~~~~~~~~
# 335 tensor([0.])
# ~~~~~~~~loss=11.908885955810547,  y=tensor([0.]) ~~~~~~~~~~
# 336 tensor([0.])
# ~~~~~~~~loss=6.581716537475586,  y=tensor([0.]) ~~~~~~~~~~
# 337 tensor([0.])
# ~~~~~~~~loss=8.21501636505127,  y=tensor([0.]) ~~~~~~~~~~
# 338 tensor([0.])
# ~~~~~~~~loss=4.210678577423096,  y=tensor([0.]) ~~~~~~~~~~
# 339 tensor([0.])
# ~~~~~~~~loss=4.015769958496094,  y=tensor([0.]) ~~~~~~~~~~
# 340 tensor([0.])
# ~~~~~~~~loss=4.981481075286865,  y=tensor([0.]) ~~~~~~~~~~
# 341 tensor([0.])
# ~~~~~~~~loss=21.815011978149414,  y=tensor([0.]) ~~~~~~~~~~
# 342 tensor([0.])
# ~~~~~~~~loss=33.4073371887207,  y=tensor([0.]) ~~~~~~~~~~
# 343 tensor([0.])
# ~~~~~~~~loss=23.615671157836914,  y=tensor([0.]) ~~~~~~~~~~
# 344 tensor([0.])
# ~~~~~~~~loss=35.57447052001953,  y=tensor([0.]) ~~~~~~~~~~
# 345 tensor([0.])
# ~~~~~~~~loss=23.253538131713867,  y=tensor([0.]) ~~~~~~~~~~
# 346 tensor([0.])
# ~~~~~~~~loss=12.380684852600098,  y=tensor([0.]) ~~~~~~~~~~
# 347 tensor([0.])
# ~~~~~~~~loss=10.888968467712402,  y=tensor([0.]) ~~~~~~~~~~
# 348 tensor([0.])
# ~~~~~~~~loss=15.157691955566406,  y=tensor([0.]) ~~~~~~~~~~
# 349 tensor([0.])
# ~~~~~~~~loss=29.900991439819336,  y=tensor([0.]) ~~~~~~~~~~
# 350 tensor([0.])
# ~~~~~~~~loss=16.140121459960938,  y=tensor([0.]) ~~~~~~~~~~
# 351 tensor([0.])
# ~~~~~~~~loss=17.92854881286621,  y=tensor([0.]) ~~~~~~~~~~
# 352 tensor([0.])
# ~~~~~~~~loss=27.163719177246094,  y=tensor([0.]) ~~~~~~~~~~
# 353 tensor([0.])
# ~~~~~~~~loss=34.0396614074707,  y=tensor([0.]) ~~~~~~~~~~
# 354 tensor([0.])
# ~~~~~~~~loss=29.953224182128906,  y=tensor([0.]) ~~~~~~~~~~
# 355 tensor([0.])
# ~~~~~~~~loss=30.197261810302734,  y=tensor([0.]) ~~~~~~~~~~
# 356 tensor([0.])
# ~~~~~~~~loss=22.003093719482422,  y=tensor([0.]) ~~~~~~~~~~
# 357 tensor([0.])
# ~~~~~~~~loss=5.169175148010254,  y=tensor([0.]) ~~~~~~~~~~
# 358 tensor([0.])
# ~~~~~~~~loss=17.2216739654541,  y=tensor([0.]) ~~~~~~~~~~
# 359 tensor([0.])
# ~~~~~~~~loss=35.137786865234375,  y=tensor([0.]) ~~~~~~~~~~
# 360 tensor([0.])
# ~~~~~~~~loss=29.918119430541992,  y=tensor([0.]) ~~~~~~~~~~
# 361 tensor([0.])
# ~~~~~~~~loss=28.98473358154297,  y=tensor([0.]) ~~~~~~~~~~
# 362 tensor([0.])
# ~~~~~~~~loss=26.764339447021484,  y=tensor([0.]) ~~~~~~~~~~
# 363 tensor([0.])
# ~~~~~~~~loss=29.19165802001953,  y=tensor([0.]) ~~~~~~~~~~
# 364 tensor([0.])
# ~~~~~~~~loss=13.320770263671875,  y=tensor([0.]) ~~~~~~~~~~
# 365 tensor([0.])
# ~~~~~~~~loss=7.325870513916016,  y=tensor([0.]) ~~~~~~~~~~
# 366 tensor([0.])
# ~~~~~~~~loss=4.141857624053955,  y=tensor([0.]) ~~~~~~~~~~
# 367 tensor([0.])
# ~~~~~~~~loss=4.007560729980469,  y=tensor([0.]) ~~~~~~~~~~
# 368 tensor([0.])
# ~~~~~~~~loss=5.282446384429932,  y=tensor([0.]) ~~~~~~~~~~
# 369 tensor([0.])
# ~~~~~~~~loss=4.237424850463867,  y=tensor([0.]) ~~~~~~~~~~
# 370 tensor([0.])
# ~~~~~~~~loss=3.6626944541931152,  y=tensor([0.]) ~~~~~~~~~~
# 371 tensor([0.])
# ~~~~~~~~loss=6.690845966339111,  y=tensor([0.]) ~~~~~~~~~~
# 372 tensor([0.])
# ~~~~~~~~loss=3.3098649978637695,  y=tensor([0.]) ~~~~~~~~~~
# 373 tensor([0.])
# ~~~~~~~~loss=7.578988552093506,  y=tensor([0.]) ~~~~~~~~~~
# 374 tensor([0.])
# ~~~~~~~~loss=3.365180015563965,  y=tensor([0.]) ~~~~~~~~~~
# 375 tensor([0.])
# ~~~~~~~~loss=3.801238536834717,  y=tensor([0.]) ~~~~~~~~~~
# 376 tensor([0.])
# ~~~~~~~~loss=10.534217834472656,  y=tensor([0.]) ~~~~~~~~~~
# 377 tensor([0.])
# ~~~~~~~~loss=8.090130805969238,  y=tensor([0.]) ~~~~~~~~~~

# %%
import pandas as pd
import matplotlib.pyplot as plt

THRESHOLD = 2 # Anomaly score threshold for an instance to be considered as anomaly 
#can set manually

#TIME_STEPS = dataset.window_length
test_score_df = pd.DataFrame(index=range(test_dataset.data_len))
test_score_df['loss'] = [loss.item()/test_dataset.window_length for loss in loss_list]
test_score_df['y'] = test_dataset.y
test_score_df['threshold'] = THRESHOLD
test_score_df['anomaly'] = test_score_df.loss > test_score_df.threshold
test_score_df['t'] = [x[59].item() for x in test_dataset.x]

plt.plot(test_score_df.index, test_score_df.loss, label='loss')
plt.plot(test_score_df.index, test_score_df.threshold, label='threshold')
plt.plot(test_score_df.index, test_score_df.y, label='y')
plt.xticks(rotation=25)
plt.legend();

# %%
import seaborn as sns

anomalies = test_score_df[test_score_df.anomaly == True]

plt.plot(
  range(test_dataset.data_len), 
  test_score_df['t'], 
  label='value'
);
# ORIGINAL
# sns.scatterplot(
#   anomalies.index,
#   anomalies.t,
#   color=sns.color_palette()[3],
#   s=52,
#   label='anomaly'
# )

sns.scatterplot(
  x=anomalies.index,
  y=anomalies.t,
  color=sns.color_palette()[3],
  s=52,
  label='anomaly'
)

plt.plot(
  range(len(test_score_df['y'])),
  test_score_df['y'],
  label='y'
)

plt.xticks(rotation=25)
plt.legend();

# %%
import numpy as np
start_end = []
state = 0
for idx in test_score_df.index:
    if state==0 and test_score_df.loc[idx, 'y']==1:
        state=1
        start = idx
    if state==1 and test_score_df.loc[idx, 'y']==0:
        state = 0
        end = idx
        start_end.append((start, end))

for s_e in start_end:
    if sum(test_score_df[s_e[0]:s_e[1]+1]['anomaly'])>0:
        for i in range(s_e[0], s_e[1]+1):
            test_score_df.loc[i, 'anomaly'] = 1
            
actual = np.array(test_score_df['y'])
predicted = np.array([int(a) for a in test_score_df['anomaly']])
# Out:
# /tmp/ipykernel_2808648/3208343193.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   test_score_df.loc[i, 'anomaly'] = 1

# %%
import numpy as np
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_curve, auc, roc_auc_score

predicted = np.array(predicted)
actual = np.array(actual)

tp = np.count_nonzero(predicted * actual)
tn = np.count_nonzero((predicted - 1) * (actual - 1))
fp = np.count_nonzero(predicted * (actual - 1))
fn = np.count_nonzero((predicted - 1) * actual)

print('True Positive\t', tp)
print('True Negative\t', tn)
print('False Positive\t', fp)
print('False Negative\t', fn)

accuracy = (tp + tn) / (tp + fp + fn + tn + 1e-9)
precision = tp / (tp + fp + 1e-9)
recall = tp / (tp + fn + 1e-9)
fmeasure = (2 * precision * recall) / (precision + recall + 1e-9)
cohen_kappa_score = cohen_kappa_score(predicted, actual)
false_positive_rate, true_positive_rate, thresholds = roc_curve(actual, predicted)
auc_val = auc(false_positive_rate, true_positive_rate)
roc_auc_val = roc_auc_score(actual, predicted)

print('Accuracy\t', accuracy)
print('Precision\t', precision)
print('Recall\t', recall)
print('f-measure\t', fmeasure)
print('cohen_kappa_score\t', cohen_kappa_score)
print('auc\t', auc_val)
print('roc_auc\t', roc_auc_val)
# Out:
# True Positive	 42
# True Negative	 328
# False Positive	 8
# False Negative	 0
# Accuracy	 0.9788359788333894
# Precision	 0.8399999999832001
# Recall	 0.9999999999761906
# f-measure	 0.9130434777448017
# cohen_kappa_score	 0.9010989010989011
# auc	 0.988095238095238
# roc_auc	 0.988095238095238

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(actual, predicted)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)

disp.plot()
plt.show()
